# %%
import pandas as pd

# %%
df = pd.read_csv("alzheimer_data_cleaned.csv", low_memory=False)

# %%
df[df["Data_Value"] == 100]
# Out:
#         Year_Start  Year_End   Location Data_Source              Class  \
# 80853         2020      2020    Midwest       BRFSS  Cognitive Decline
# 83960         2020      2020    Midwest       BRFSS  Cognitive Decline
# 88697         2020      2020    Midwest       BRFSS         Caregiving
# 134846        2020      2020  Northeast       BRFSS  Cognitive Decline
# 135630        2019      2019  Northeast       BRFSS  Cognitive Decline
# 137152        2020      2020  Northeast       BRFSS         Caregiving
# 137341        2020      2020  Northeast       BRFSS         Caregiving
# 137846        2020      2020  Northeast       BRFSS         Caregiving
# 138053        2020      2020  Northeast       BRFSS         Caregiving
# 138086        2020      2020  Northeast       BRFSS  Cognitive Decline
# 141947        2020      2020  Northeast       BRFSS  Cognitive Decline
# 157941        2020      2020      South       BRFSS  Cognitive Decline
# ...
